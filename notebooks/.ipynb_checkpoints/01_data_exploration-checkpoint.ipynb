# %%
import pandas as pd

# Load Bot-IoT dataset
bot_iot_path = r"C:\Users\User\IIoT_IDS_Project\data\raw\bot-iot\UNSW_2018_IoT_Botnet_Final_10_best_Training.csv"
bot_df = pd.read_csv(bot_iot_path)

# Show basic info
print("Bot-IoT dataset shape:", bot_df.shape)
print("\nColumns:", bot_df.columns.tolist())
print("\nData types:\n", bot_df.dtypes)
print("\nMissing values:\n", bot_df.isnull().sum())
print("\nFirst 5 rows:\n", bot_df.head())

# Class distribution
print("\nClass distribution (attack column):\n", bot_df['attack'].value_counts())
# Out:
# Bot-IoT dataset shape: (2934817, 19)
#
# Columns: ['pkSeqID', 'proto', 'saddr', 'sport', 'daddr', 'dport', 'seq', 'stddev', 'N_IN_Conn_P_SrcIP', 'min', 'state_number', 'mean', 'N_IN_Conn_P_DstIP', 'drate', 'srate', 'max', 'attack', 'category', 'subcategory']
#
# Data types:
#  pkSeqID                int64
# proto                 object
# saddr                 object
# sport                 object
# daddr                 object
# dport                 object
# seq                    int64
# stddev               float64
# N_IN_Conn_P_SrcIP      int64
# min                  float64
# state_number           int64
# mean                 float64
# N_IN_Conn_P_DstIP      int64
# drate                float64
# srate                float64
# max                  float64
# attack                 int64
# category              object
# subcategory           object
# dtype: object
#
# Missing values:
#  pkSeqID              0
# proto                0
# saddr                0
# ...

# %%
# Load TON-IoT Modbus dataset
ton_iot_path =r"C:\Users\User\IIoT_IDS_Project\data\raw\ton-iot\Train_Test_IoT_Modbus.csv"
ton_df = pd.read_csv(ton_iot_path)

# Show basic info
print("\nTON-IoT-Modbus dataset shape:", ton_df.shape)
print("\nColumns:", ton_df.columns.tolist())
print("\nData types:\n", ton_df.dtypes)
print("\nMissing values:\n", ton_df.isnull().sum())
print("\nFirst 5 rows:\n", ton_df.head())

# Class distribution
print("\nClass distribution (label column):\n", ton_df['label'].value_counts())
